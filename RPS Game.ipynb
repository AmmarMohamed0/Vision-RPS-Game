# %%
import cv2
import numpy as np
import time
from ultralytics import YOLO

# Load the YOLO model with specified weights
model = YOLO("best.pt")

# Open a connection to the webcam (0 is usually the default camera)
cap = cv2.VideoCapture(0)

# Define the gesture classes
All_Classes = ['Paper', 'Rock', 'Scissors']

# Initialize scores and timer variables
Player1_Score = 0
Player2_Score = 0
Last_update_time = time.time()  # Time of the last score update
update_interval = 5  # Minimum interval between score updates in seconds

# Function to determine the winner between two gestures
def determine_winner(gesture1, gesture2):
    if gesture1 == gesture2:
        return 0  # It's a tie
    elif (gesture1 == 'Rock' and gesture2 == 'Scissors') or \
         (gesture1 == 'Scissors' and gesture2 == 'Paper') or \
         (gesture1 == 'Paper' and gesture2 == 'Rock'):
        return 1  # Player 1 wins
    else:
        return 2  # Player 2 wins

# Main loop to process the video frames
while True:
    # Capture a frame from the webcam
    ret, frame = cap.read()
    if not ret:
        break  # Break the loop if frame capture fails
    
    # Resize the frame for processing
    frame = cv2.resize(frame, (1020, 500))
    
    # Use the YOLO model to track objects in the frame
    results = model.track(frame)
    
    # Ensure the results contain bounding boxes
    if len(results) > 0 and hasattr(results[0], 'boxes'):
        # Extract bounding boxes, confidences, and class labels
        boxes = results[0].boxes.xyxy.cpu().numpy()
        confs = results[0].boxes.conf.cpu().numpy()
        classes = results[0].boxes.cls.cpu().numpy().astype(int)

        Player1_gesture = None
        Player2_gesture = None

        # Iterate over detected objects
        for box, conf, cls in zip(boxes, confs, classes):
            if conf > 0.25:  # Process only if confidence is greater than 0.25
                x1, y1, x2, y2 = map(int, box)  # Convert box coordinates to integers
                gesture = All_Classes[cls]  # Get gesture name from class index
                label = f"{gesture}: {conf:.2f}"  # Create label text with gesture and confidence

                # Determine which player the gesture belongs to based on horizontal position
                cx = (x1 + x2) // 2  # Calculate center x-coordinate of the bounding box
                if cx < frame.shape[1] // 2:  # Left half of the frame
                    Player1_gesture = gesture
                else:  # Right half of the frame
                    Player2_gesture = gesture

                # Draw bounding box and label on the frame
                cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
                cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

        # Check if both players have made a gesture and if the update interval has passed
        current_time = time.time()
        if Player1_gesture and Player2_gesture and current_time - Last_update_time > update_interval:
            # Determine the winner and update scores
            winner = determine_winner(Player1_gesture, Player2_gesture)
            if winner == 1:
                Player1_Score += 1
            elif winner == 2:
                Player2_Score += 1
            Last_update_time = current_time  # Update the last score update time

    # Display the scores on the frame
    score_text = f"Player one: {Player1_Score}  Player two: {Player2_Score}"
    cv2.putText(frame, score_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

    # Show the processed frame in a window
    cv2.imshow("Rock, Paper, Scissors Game", frame)

    # Exit the loop if the 'Esc' key is pressed
    key = cv2.waitKey(1) & 0xFF
    if key == 27:  # ESC key
        break

# Release the video capture object and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 (no detections), 28.7ms
# Speed: 3.8ms preprocess, 28.7ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 25.7ms
# Speed: 11.4ms preprocess, 25.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 28.9ms
# Speed: 0.0ms preprocess, 28.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 26.3ms
# Speed: 6.6ms preprocess, 26.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 27.3ms
# Speed: 6.8ms preprocess, 27.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.5ms
# Speed: 0.5ms preprocess, 20.5ms inference, 7.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.3ms
# Speed: 0.0ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 6.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 26.5ms
# Speed: 5.4ms preprocess, 26.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 22.3ms
# Speed: 0.0ms preprocess, 22.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.3ms
# Speed: 0.0ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.2ms
# Speed: 2.0ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.6ms
# Speed: 1.8ms preprocess, 19.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 0.6ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.6ms
# Speed: 1.0ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 22.7ms
# Speed: 0.0ms preprocess, 22.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.8ms
# Speed: 2.4ms preprocess, 19.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.1ms
# Speed: 0.0ms preprocess, 21.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.5ms
# Speed: 7.7ms preprocess, 20.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.2ms
# Speed: 2.2ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 22.6ms
# Speed: 0.0ms preprocess, 22.6ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.6ms
# Speed: 0.0ms preprocess, 20.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.9ms
# Speed: 0.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.2ms
# Speed: 0.6ms preprocess, 20.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.9ms
# Speed: 1.4ms preprocess, 19.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Scissors, 20.3ms
# Speed: 0.0ms preprocess, 20.3ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.1ms
# Speed: 1.7ms preprocess, 19.1ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.9ms
# Speed: 0.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 20.2ms
# Speed: 0.0ms preprocess, 20.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 21.1ms
# Speed: 0.0ms preprocess, 21.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 14.8ms
# Speed: 4.2ms preprocess, 14.8ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 14.0ms
# Speed: 6.9ms preprocess, 14.0ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.3ms
# Speed: 0.0ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 23.8ms
# Speed: 0.0ms preprocess, 23.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.1ms
# Speed: 0.0ms preprocess, 20.1ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.1ms
# Speed: 5.5ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.0ms
# Speed: 7.2ms preprocess, 16.0ms inference, 3.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.0ms
# Speed: 1.6ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.1ms
# Speed: 0.0ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.6ms
# Speed: 1.2ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.4ms
# Speed: 8.4ms preprocess, 16.4ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.6ms
# Speed: 0.0ms preprocess, 20.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 21.1ms
# Speed: 0.0ms preprocess, 21.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 16.0ms
# Speed: 7.0ms preprocess, 16.0ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 12.9ms
# Speed: 1.8ms preprocess, 12.9ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 4.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 20.6ms
# Speed: 0.0ms preprocess, 20.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 20.3ms
# Speed: 0.0ms preprocess, 20.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.3ms
# Speed: 1.0ms preprocess, 18.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.6ms
# Speed: 0.0ms preprocess, 20.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 24.3ms
# Speed: 0.0ms preprocess, 24.3ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 23.8ms
# Speed: 0.0ms preprocess, 23.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.9ms
# Speed: 0.8ms preprocess, 18.9ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.4ms
# Speed: 0.0ms preprocess, 20.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.6ms
# Speed: 0.0ms preprocess, 19.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.1ms
# Speed: 0.5ms preprocess, 17.1ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.2ms
# Speed: 0.0ms preprocess, 14.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 22.7ms
# Speed: 0.0ms preprocess, 22.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.4ms
# Speed: 0.0ms preprocess, 21.4ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.6ms
# Speed: 0.0ms preprocess, 19.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.9ms
# Speed: 0.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 20.1ms
# Speed: 0.0ms preprocess, 20.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 23.4ms
# Speed: 0.0ms preprocess, 23.4ms inference, 0.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 21.1ms
# Speed: 0.0ms preprocess, 21.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 14.1ms
# Speed: 7.4ms preprocess, 14.1ms inference, 7.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 20.9ms
# Speed: 0.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 19.4ms
# Speed: 1.5ms preprocess, 19.4ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 20.9ms
# Speed: 0.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 28.1ms
# Speed: 0.0ms preprocess, 28.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 13.8ms
# Speed: 2.1ms preprocess, 13.8ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 23.3ms
# Speed: 0.0ms preprocess, 23.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.3ms
# Speed: 2.0ms preprocess, 20.3ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 24.1ms
# Speed: 0.0ms preprocess, 24.1ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.5ms
# Speed: 0.0ms preprocess, 18.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 1 Rock, 16.8ms
# Speed: 5.7ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 23.5ms
# Speed: 0.0ms preprocess, 23.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 12.1ms
# Speed: 2.3ms preprocess, 12.1ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 15.5ms
# Speed: 0.0ms preprocess, 15.5ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 13.9ms
# Speed: 0.0ms preprocess, 13.9ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 24.9ms
# Speed: 0.0ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 12.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 17.6ms
# Speed: 1.5ms preprocess, 17.6ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 21.1ms
# Speed: 0.0ms preprocess, 21.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 13.9ms
# Speed: 0.0ms preprocess, 13.9ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 1 Rock, 25.3ms
# Speed: 0.0ms preprocess, 25.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 1 Rock, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 1 Rock, 13.9ms
# Speed: 0.0ms preprocess, 13.9ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 16.6ms
# Speed: 3.0ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.4ms
# Speed: 0.5ms preprocess, 16.4ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 13.9ms
# Speed: 0.0ms preprocess, 13.9ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 13.9ms
# Speed: 0.0ms preprocess, 13.9ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 1 Rock, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 1 Rock, 13.9ms
# Speed: 0.0ms preprocess, 13.9ms inference, 8.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 17.3ms
# Speed: 4.0ms preprocess, 17.3ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 17.9ms
# Speed: 1.0ms preprocess, 17.9ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 20.0ms
# Speed: 0.0ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.4ms
# Speed: 0.0ms preprocess, 19.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 18.0ms
# Speed: 0.9ms preprocess, 18.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 18.6ms
# Speed: 1.0ms preprocess, 18.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.7ms
# Speed: 1.5ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 2 Rocks, 17.1ms
# Speed: 7.2ms preprocess, 17.1ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 2 Rocks, 17.5ms
# Speed: 2.0ms preprocess, 17.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 2 Rocks, 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 1 Rock, 20.3ms
# Speed: 0.0ms preprocess, 20.3ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 1 Rock, 19.7ms
# Speed: 0.0ms preprocess, 19.7ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.4ms
# Speed: 2.0ms preprocess, 19.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 13.1ms
# Speed: 1.1ms preprocess, 13.1ms inference, 8.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 18.5ms
# Speed: 2.0ms preprocess, 18.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 21.9ms
# Speed: 0.0ms preprocess, 21.9ms inference, 7.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 17.9ms
# Speed: 1.5ms preprocess, 17.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.6ms
# Speed: 1.1ms preprocess, 19.6ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 17.4ms
# Speed: 6.9ms preprocess, 17.4ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 24.1ms
# Speed: 0.0ms preprocess, 24.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 17.3ms
# Speed: 1.0ms preprocess, 17.3ms inference, 3.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 1 Rock, 21.3ms
# Speed: 0.0ms preprocess, 21.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 1 Rock, 18.3ms
# Speed: 1.0ms preprocess, 18.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 32.9ms
# Speed: 2.0ms preprocess, 32.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 23.0ms
# Speed: 0.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.6ms
# Speed: 1.0ms preprocess, 19.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.6ms
# Speed: 0.8ms preprocess, 19.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.2ms
# Speed: 1.1ms preprocess, 16.2ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.4ms
# Speed: 3.2ms preprocess, 16.4ms inference, 4.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.7ms
# Speed: 2.0ms preprocess, 19.7ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 17.1ms
# Speed: 1.6ms preprocess, 17.1ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 14.4ms
# Speed: 1.2ms preprocess, 14.4ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 1 Rock, 16.1ms
# Speed: 7.0ms preprocess, 16.1ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 1 Rock, 21.4ms
# Speed: 0.0ms preprocess, 21.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 1 Rock, 18.6ms
# Speed: 1.0ms preprocess, 18.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.2ms
# Speed: 2.0ms preprocess, 19.2ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 17.2ms
# Speed: 7.0ms preprocess, 17.2ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 20.0ms
# Speed: 1.0ms preprocess, 20.0ms inference, 3.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 21.6ms
# Speed: 0.0ms preprocess, 21.6ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.3ms
# Speed: 2.0ms preprocess, 19.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 18.4ms
# Speed: 2.0ms preprocess, 18.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 17.8ms
# Speed: 1.0ms preprocess, 17.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.1ms
# Speed: 3.1ms preprocess, 19.1ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 18.6ms
# Speed: 2.1ms preprocess, 18.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.0ms
# Speed: 1.0ms preprocess, 16.0ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.5ms
# Speed: 1.0ms preprocess, 19.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.6ms
# Speed: 5.6ms preprocess, 16.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.9ms
# Speed: 0.0ms preprocess, 21.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 1 Rock, 20.8ms
# Speed: 0.0ms preprocess, 20.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.3ms
# Speed: 0.0ms preprocess, 19.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 12.3ms
# Speed: 1.0ms preprocess, 12.3ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.1ms
# Speed: 0.0ms preprocess, 17.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 11.8ms
# Speed: 2.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 10.4ms
# Speed: 1.0ms preprocess, 10.4ms inference, 8.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.9ms
# Speed: 0.0ms preprocess, 19.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 11.1ms
# Speed: 2.1ms preprocess, 11.1ms inference, 6.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 15.7ms
# Speed: 7.1ms preprocess, 15.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 20.9ms
# Speed: 0.0ms preprocess, 20.9ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 18.3ms
# Speed: 1.0ms preprocess, 18.3ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 14.1ms
# Speed: 0.0ms preprocess, 14.1ms inference, 2.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.1ms
# Speed: 0.0ms preprocess, 19.1ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 15.1ms
# Speed: 1.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 13.6ms
# Speed: 0.0ms preprocess, 13.6ms inference, 7.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 8.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 16.8ms
# Speed: 1.0ms preprocess, 16.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Rock, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 6.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.8ms
# Speed: 1.1ms preprocess, 16.8ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 15.6ms
# Speed: 2.3ms preprocess, 15.6ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 15.9ms
# Speed: 6.2ms preprocess, 15.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.6ms
# Speed: 0.0ms preprocess, 19.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 21.6ms
# Speed: 0.0ms preprocess, 21.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 13.7ms
# Speed: 0.0ms preprocess, 13.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 3.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 22.4ms
# Speed: 0.0ms preprocess, 22.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 20.1ms
# Speed: 0.0ms preprocess, 20.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 21.7ms
# Speed: 0.0ms preprocess, 21.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 13.8ms
# Speed: 0.5ms preprocess, 13.8ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 2.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 22.1ms
# Speed: 0.0ms preprocess, 22.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 20.0ms
# Speed: 0.0ms preprocess, 20.0ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 15.9ms
# Speed: 7.0ms preprocess, 15.9ms inference, 4.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.8ms
# Speed: 4.2ms preprocess, 18.8ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.3ms
# Speed: 1.0ms preprocess, 18.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 18.2ms
# Speed: 2.0ms preprocess, 18.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.0ms
# Speed: 6.8ms preprocess, 16.0ms inference, 4.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.5ms
# Speed: 0.4ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.1ms
# Speed: 3.3ms preprocess, 16.1ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.9ms
# Speed: 0.0ms preprocess, 16.9ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.7ms
# Speed: 0.0ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.6ms
# Speed: 2.0ms preprocess, 12.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.7ms
# Speed: 0.0ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 12.7ms
# Speed: 2.0ms preprocess, 12.7ms inference, 5.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 15.7ms
# Speed: 2.0ms preprocess, 15.7ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 20.9ms
# Speed: 0.0ms preprocess, 20.9ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Papers, 21.0ms
# Speed: 0.0ms preprocess, 21.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 15.8ms
# Speed: 6.5ms preprocess, 15.8ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 12.8ms
# Speed: 1.6ms preprocess, 12.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 6.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 15.1ms
# Speed: 0.0ms preprocess, 15.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 15.8ms
# Speed: 1.0ms preprocess, 15.8ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 15.9ms
# Speed: 1.6ms preprocess, 15.9ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 17.8ms
# Speed: 0.0ms preprocess, 17.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 12.5ms
# Speed: 0.0ms preprocess, 12.5ms inference, 7.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 14.2ms
# Speed: 0.0ms preprocess, 14.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.7ms
# Speed: 0.0ms preprocess, 19.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 11.0ms
# Speed: 1.0ms preprocess, 11.0ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 6.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 15.8ms
# Speed: 6.6ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 13.8ms
# Speed: 1.0ms preprocess, 13.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 17.8ms
# Speed: 0.0ms preprocess, 17.8ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.7ms
# Speed: 3.0ms preprocess, 19.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.8ms
# Speed: 2.2ms preprocess, 16.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.3ms
# Speed: 0.0ms preprocess, 18.3ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.5ms
# Speed: 0.0ms preprocess, 19.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.3ms
# Speed: 1.0ms preprocess, 19.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.9ms
# Speed: 2.0ms preprocess, 19.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.8ms
# Speed: 0.0ms preprocess, 19.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.4ms
# Speed: 1.0ms preprocess, 18.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.6ms
# Speed: 2.7ms preprocess, 19.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.1ms
# Speed: 1.0ms preprocess, 18.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.4ms
# Speed: 1.1ms preprocess, 18.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.8ms
# Speed: 6.5ms preprocess, 16.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.0ms
# Speed: 4.3ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.8ms
# Speed: 2.5ms preprocess, 17.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.6ms
# Speed: 1.5ms preprocess, 15.6ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 17.2ms
# Speed: 1.0ms preprocess, 17.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.6ms
# Speed: 2.0ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 16.7ms
# Speed: 2.3ms preprocess, 16.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 22.4ms
# Speed: 0.0ms preprocess, 22.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 19.2ms
# Speed: 0.0ms preprocess, 19.2ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Paper, 23.9ms
# Speed: 0.0ms preprocess, 23.9ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.3ms
# Speed: 1.9ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.4ms
# Speed: 1.0ms preprocess, 13.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Scissorss, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 7.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Scissors, 16.7ms
# Speed: 2.0ms preprocess, 16.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Scissors, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 8.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Scissorss, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Scissorss, 13.5ms
# Speed: 0.0ms preprocess, 13.5ms inference, 7.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Scissorss, 21.2ms
# Speed: 0.0ms preprocess, 21.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Scissors, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 5.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Scissors, 14.4ms
# Speed: 2.4ms preprocess, 14.4ms inference, 4.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 1 Scissors, 20.2ms
# Speed: 0.0ms preprocess, 20.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.9ms
# Speed: 6.0ms preprocess, 15.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.4ms
# Speed: 0.0ms preprocess, 17.4ms inference, 2.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.5ms
# Speed: 0.0ms preprocess, 20.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 21.5ms
# Speed: 0.0ms preprocess, 21.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.7ms
# Speed: 5.9ms preprocess, 14.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.6ms
# Speed: 0.0ms preprocess, 18.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.4ms
# Speed: 0.0ms preprocess, 20.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 6.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.1ms
# Speed: 0.0ms preprocess, 20.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 22.8ms
# Speed: 0.0ms preprocess, 22.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.4ms
# Speed: 2.0ms preprocess, 17.4ms inference, 0.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.4ms
# Speed: 3.1ms preprocess, 17.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 18.0ms
# Speed: 1.0ms preprocess, 18.0ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.7ms
# Speed: 1.0ms preprocess, 17.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.8ms
# Speed: 1.0ms preprocess, 15.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.7ms
# Speed: 1.0ms preprocess, 16.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.3ms
# Speed: 0.0ms preprocess, 19.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.7ms
# Speed: 0.9ms preprocess, 17.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.2ms
# Speed: 0.0ms preprocess, 19.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.4ms
# Speed: 3.0ms preprocess, 17.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 17.4ms
# Speed: 1.3ms preprocess, 17.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.1ms
# Speed: 1.0ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.7ms
# Speed: 6.0ms preprocess, 15.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 20.4ms
# Speed: 0.0ms preprocess, 20.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.6ms
# Speed: 0.0ms preprocess, 13.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.8ms
# Speed: 7.4ms preprocess, 15.8ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.3ms
# Speed: 6.9ms preprocess, 16.3ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 19.5ms
# Speed: 0.0ms preprocess, 19.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 16.3ms
# Speed: 7.6ms preprocess, 16.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 15.0ms
# Speed: 6.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 14.9ms
# Speed: 1.7ms preprocess, 14.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 (no detections), 13.8ms
# Speed: 0.0ms preprocess, 13.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
